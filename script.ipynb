-- %% [markdown]
-- # [Prueba_Rapida]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Prueba_Rapida]    Script Date: 7/8/2022 23:11:07 ******/
CREATE DATABASE [Prueba_Rapida]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Prueba_Rapida', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\Prueba_Rapida.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Prueba_Rapida_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\Prueba_Rapida_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [Prueba_Rapida] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Prueba_Rapida].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Prueba_Rapida] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET ARITHABORT OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Prueba_Rapida] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Prueba_Rapida] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Prueba_Rapida] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Prueba_Rapida] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Prueba_Rapida] SET  MULTI_USER 
GO
ALTER DATABASE [Prueba_Rapida] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Prueba_Rapida] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Prueba_Rapida] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Prueba_Rapida] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Prueba_Rapida] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Prueba_Rapida] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Prueba_Rapida] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[CLIENTES]

-- %%
USE [Prueba_Rapida]
GO

-- %%
/****** Object:  Table [dbo].[CLIENTES]    Script Date: 7/8/2022 23:11:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CLIENTES](
	[RUC] [varchar](50) NOT NULL,
	[RAZON_SOCIAL] [varchar](50) NULL,
	[FECHA_CONSTITUCION] [date] NULL,
	[ESTADO] [bit] NULL,
 CONSTRAINT [PK_CLIENTES] PRIMARY KEY CLUSTERED 
(
	[RUC] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FACTURAS]

-- %%
/****** Object:  Table [dbo].[FACTURAS]    Script Date: 7/8/2022 23:11:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FACTURAS](
	[NUMERO_FACTURA] [int] IDENTITY(1,1) NOT NULL,
	[FECHA] [date] NULL,
	[IMPORTE_TOTAL] [int] NULL,
	[RUC] [varchar](50) NULL,
 CONSTRAINT [PK_FACTURAS] PRIMARY KEY CLUSTERED 
(
	[NUMERO_FACTURA] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cliente_Create]

-- %%
/****** Object:  StoredProcedure [dbo].[Cliente_Create]    Script Date: 7/8/2022 23:11:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[Cliente_Create]
	   @RUC varchar(20),
	   @RAZON_SOCIAL varchar(20),
	   @FECHA_CONSTITUCION	date,
	   @ESTADO bit
	 
AS
BEGIN
INSERT INTO [dbo].[CLIENTES]
           ([RUC]
           ,[RAZON_SOCIAL]
           ,[FECHA_CONSTITUCION]
           ,[ESTADO])
    VALUES (
	   @RUC,
	   @RAZON_SOCIAL,
	   @FECHA_CONSTITUCION,
	   @ESTADO)
 

END
GO

-- %% [markdown]
-- # [dbo].[Cliente_Update]

-- %%
/****** Object:  StoredProcedure [dbo].[Cliente_Update]    Script Date: 7/8/2022 23:11:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[Cliente_Update]
	   @RUC varchar(20),
	   @ESTADO bit
	 
AS
BEGIN
UPDATE [dbo].[CLIENTES] SET ESTADO = @ESTADO WHERE RUC = @RUC

END
GO

-- %% [markdown]
-- # [dbo].[Facturas_Insertar]

-- %%
/****** Object:  StoredProcedure [dbo].[Facturas_Insertar]    Script Date: 7/8/2022 23:11:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[Facturas_Insertar]
	   @RUC varchar(20),
	   @IMPORTE INT
	 
AS
BEGIN
INSERT INTO [dbo].[FACTURAS]
           ([FECHA]
           ,[IMPORTE_TOTAL]
           ,[RUC])
     VALUES
           (GETDATE()
           ,@IMPORTE
           ,@RUC)
END
GO

-- %% [markdown]
-- # [dbo].[Facturas_Total]

-- %%
/****** Object:  StoredProcedure [dbo].[Facturas_Total]    Script Date: 7/8/2022 23:11:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[Facturas_Total]
	   @RUC varchar(20),
	   @Mensaje varchar(50) OUTPUT
	 
AS
BEGIN
SET @Mensaje = CONVERT(VARCHAR,COALESCE((SELECT SUM(IMPORTE_TOTAL) FROM FACTURAS WHERE RUC = @RUC),0))

END
GO

-- %% [markdown]
-- # [Prueba_Rapida]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Prueba_Rapida] SET  READ_WRITE 
GO
